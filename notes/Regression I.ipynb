# %% [markdown]
# # Regression I

# %% [markdown]
# ## 7.3 Regression
#
# - classification: predicts categorical
# - regression : predicts numerical
#
# ## 7.5 $K$ nearest neighbors regression
#
# - Take the average of near neighbors
# - can work with non-linear relationships
#
# ## 7.6 Training, evaluationg, and tuning
# - Root mean square prediction error
#     -squred difference between predicted and true value
# ![image.png](attachment:aed3c2c0-6b0e-4178-ae74-cfeacc9be996.png)
# - choose $K$ that gives the smallest RMSPE
# ![image.png](attachment:23cfb0eb-016d-4f66-a93f-efda635abea2.png)
# - Cross-validation
# ![image.png](attachment:6e11d155-d191-43b2-959f-9d85f3cc5db3.png)

# %% [markdown]
# ## 7.7 Underfitting and overfitting
# - Small $K$ line following trainingdata closely- influneced too much by training data
# - Large $K$ line becomes extremely smooth- not influence enough
# -
